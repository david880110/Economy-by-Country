# %%
import pandas as pd
import numpy as np

# %%
# Load data
df_gdp_mainlandchina = pd.read_csv('raw_data/data-gdp-mainlandchina-2019.csv')  
df_gdp_usa = pd.read_csv('raw_data/data-gdp-usa-2019.csv')  
df_pop_china = pd.read_csv('raw_data/data-pop-china-2017.csv')  
df_pop_usa = pd.read_csv('raw_data/data-pop-usa-2019.csv')  
df_WEO = pd.read_csv('raw_data/WEO_Data.csv')  
df_region_china = pd.read_csv('raw_data/data-economyregion-china.csv')

# %% [markdown]
# # China

# %%
# Merge dataframe for China
df_china = pd.DataFrame.merge(df_gdp_mainlandchina,df_pop_china,how='right',left_on='Provinces',right_on='Administrative Division')
df_china = pd.DataFrame.merge(df_china,df_region_china,how='left',left_on='Administrative Division',right_on='Provinces')

# Don't show Unnamed columns
df_china = df_china.loc[:, ~df_china.columns.str.contains('^Unnamed')] 

# Drop column
df_china = df_china.drop(['Provinces_x'], axis=1)
df_china = df_china.drop(['Provinces_y'], axis=1)

# Add column
df_china['Country'] = 'China'
df_china['Year'] = '2019'

df_china.tail()
# Out:
#     Nominal GDP (Billion) Administrative Division  Population     Region  \
# 29                   43.0                 Qinghai     5980000       West
# 30                   25.0                   Tibet     3370000       West
# 31                    NaN               Hong Kong     7335384  Hong Kong
# 32                    NaN                   Macau      644900      Macau
# 33                    NaN                  Taiwan    23562318     Taiwan
#
#     Economic Zone #          Economic Zone         经济区  \
# 29               10  Qinghai-Tibet Plateau     青藏高原经济区
# 30               10  Qinghai-Tibet Plateau     青藏高原经济区
# 31               11              Hong Kong     香港特别行政区
# 32               12                  Macau    澳门港特别行政区
# 33               13                 Taiwan  台澎金马个别关税领域
#
#                                        Characteristic Country  Year
# 29  Natural gas, salt lake resources, non-ferrous ...   China  2019
# 30  Natural gas, salt lake resources, non-ferrous ...   China  2019
# 31  Trade and logistics industry (21.2%), financia...   China  2019
# 32                 Tourism and apparel industry (41%)   China  2019
# 33                      Agricultural products and OEM   China  2019

# %%
# Get GDP value for Hong Kong, Macau and Taiwan
df_hongkong = df_WEO[df_WEO['Country'].str.contains('hong kong', case=False, na=False)]
hongkong_gdp = df_hongkong.loc[df_hongkong['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

df_macau = df_WEO[df_WEO['Country'].str.contains('maca', case=False, na=False)]
macau_gdp = df_macau.loc[df_macau['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

df_taiwan = df_WEO[df_WEO['Country'].str.contains('taiwan', case=False, na=False)]
taiwan_gdp = df_taiwan.loc[df_taiwan['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

print('Hong Kong GDP: ',hongkong_gdp)
print('Macau GDP: ',macau_gdp)
print('Taiwan GDP: ',taiwan_gdp)
# Out:
# Hong Kong GDP:  372.989
# Macau GDP:  55.136
# Taiwan GDP:  586.104

# %%
# Assign value
## to Hong Kong
hongkong_index = df_china.loc[df_china['Administrative Division'] == 'Hong Kong'].index[0]
df_china.at[hongkong_index, 'Nominal GDP (Billion)'] = hongkong_gdp

## to Macau
macau_index = df_china.loc[df_china['Administrative Division'] == 'Macau'].index[0]
df_china.at[macau_index, 'Nominal GDP (Billion)'] = macau_gdp

## to Taiwan 
taiwan_index = df_china.loc[df_china['Administrative Division'] == 'Taiwan'].index[0]
df_china.at[taiwan_index, 'Nominal GDP (Billion)'] = taiwan_gdp

# Calculate GDP per Capita
df_china['GDP per Capita'] = (df_china['Nominal GDP (Billion)'] / df_china['Population'])*1000000000

# Re-order Columns
df_china = df_china[['Year','Country','Region','Economic Zone #','Economic Zone','Administrative Division','Nominal GDP (Billion)','Population','GDP per Capita','Characteristic']]

# Set 0 decimal places
df_china['GDP per Capita'] = df_china['GDP per Capita'].round(0)

df_china
# Out:
#     Year Country                   Region  Economic Zone #  \
# 0   2019   China                     East                4
# 1   2019   China                     East                3
# 2   2019   China                     East                2
# 3   2019   China                     East                3
# 4   2019   China                   Middle                5
# 5   2019   China                     West                6
# 6   2019   China                   Middle                6
# 7   2019   China                     East                4
# 8   2019   China                   Middle                6
# 9   2019   China                     East                3
# 10  2019   China                   Middle                6
# 11  2019   China                     East                2
# 12  2019   China                     East                2
# 13  2019   China                     West                5
# 14  2019   China  Northeast Comprehensive                1
# 15  2019   China                   Middle                6
# 16  2019   China                     West                6
# 17  2019   China                     West                7
# 18  2019   China                     West                7
# 19  2019   China                     West                8
# 20  2019   China                   Middle                5
# 21  2019   China                     West                7
# 22  2019   China                     East                2
# 23  2019   China  Northeast Comprehensive                1
# 24  2019   China                     West                9
# 25  2019   China  Northeast Comprehensive                1
# 26  2019   China                     West                5
# 27  2019   China                     East                4
# 28  2019   China                     West                5
# 29  2019   China                     West               10
# 30  2019   China                     West               10
# 31  2019   China                Hong Kong               11
# 32  2019   China                    Macau               12
# 33  2019   China                   Taiwan               13
#
#                              Economic Zone Administrative Division  \
# 0                          Southeast Coast               Guangdong
# 1                               East Coast                 Jiangsu
# 2                              North Coast                Shandong
# 3                               East Coast                Zhejiang
# 4    Yellow River Upper and Middle Reaches                   Henan
# 5   Yangtze River Upper and Middle Reaches                 Sichuan
# 6   Yangtze River Upper and Middle Reaches                   Hubei
# 7                          Southeast Coast                  Fujian
# 8   Yangtze River Upper and Middle Reaches                   Hunan
# 9                               East Coast                Shanghai
# 10  Yangtze River Upper and Middle Reaches                   Anhui
# 11                             North Coast                 Beijing
# 12                             North Coast                   Hebei
# 13   Yellow River Upper and Middle Reaches                 Shaanxi
# 14                 Northeast Comprehensive                Liaoning
# 15  Yangtze River Upper and Middle Reaches                 Jiangxi
# 16  Yangtze River Upper and Middle Reaches               Chongqing
# 17             Pearl River Upper Midstream                  Yunnan
# 18             Pearl River Upper Midstream                 Guangxi
# 19                          Inner Mongolia          Inner Mongolia
# 20   Yellow River Upper and Middle Reaches                  Shanxi
# 21             Pearl River Upper Midstream                 Guizhou
# 22                             North Coast                 Tianjin
# 23                 Northeast Comprehensive            Heilongjiang
# 29  Natural gas, salt lake resources, non-ferrous ...
# 30  Natural gas, salt lake resources, non-ferrous ...
# 31  Trade and logistics industry (21.2%), financia...
# 32                 Tourism and apparel industry (41%)
# 33                      Agricultural products and OEM

# %% [markdown]
# # USA

# %%
df_gdp_usa.head()
# Out:
#             State  Nominal GDP (Billion)
# 0     Connecticut                1142561
# 1          Maine                  270074
# 2  Massachusetts                 2382235
# 3  New Hampshire                  354379
# 4   Rhode Island                  254164

# %%
df_pop_usa.head()
# Out:
#            State  Population
# 0     California    39512223
# 1          Texas    28995881
# 2        Florida    21477737
# 3       New York    19453561
# 4   Pennsylvania    12801989

# %%
# Strip leading and trailng white space in State column
df_gdp_usa['State'] = df_gdp_usa['State'].str.strip()
df_pop_usa['State'] = df_pop_usa['State'].str.strip()

# Merge dataframe for China
df_usa = pd.DataFrame.merge(df_gdp_usa,df_pop_usa,how='left',on='State')

# Add column
df_usa['Country'] = 'United States'
df_usa['Year'] = '2019'

# Rename column
df_usa.rename(columns={'State':'Administrative Division'}, inplace=True)

# Re-order Columns
df_usa = df_usa[['Year','Country','Administrative Division','Nominal GDP (Billion)','Population']]

# Calculate GDP per Capita
df_usa['GDP per Capita'] = (df_usa['Nominal GDP (Billion)'] / df_usa['Population'])*1000000000

# Set 0 decimal places
df_usa['GDP per Capita'] = df_usa['GDP per Capita'].round(0)

df_usa
# Out:
#     Year        Country Administrative Division  Nominal GDP (Billion)  \
# 0   2019  United States             Connecticut                1142561
# 1   2019  United States                   Maine                 270074
# 2   2019  United States           Massachusetts                2382235
# 3   2019  United States           New Hampshire                 354379
# 4   2019  United States            Rhode Island                 254164
# 5   2019  United States                 Vermont                 139140
# 6   2019  United States                Delaware                 301661
# 7   2019  United States    District of Columbia                 584778
# 8   2019  United States                Maryland                1713354
# 9   2019  United States              New Jersey                2579366
# 10  2019  United States                New York                6927642
# 11  2019  United States            Pennsylvania                3254054
# 12  2019  United States                Illinois                3588495
# 13  2019  United States                 Indiana                1508418
# 14  2019  United States                Michigan                2166203
# 15  2019  United States                    Ohio                2793832
# 16  2019  United States               Wisconsin                1389224
# 17  2019  United States                    Iowa                 779154
# 18  2019  United States                  Kansas                 692569
# 19  2019  United States               Minnesota                1523420
# 20  2019  United States                Missouri                1328328
# 21  2019  United States                Nebraska                 508147
# 22  2019  United States            North Dakota                 228146
# 23  2019  United States            South Dakota                 213223
# 24  2019  United States                 Alabama                 923873
# 25  2019  United States                Arkansas                 532723
# 26  2019  United States                 Florida                4373403
# 27  2019  United States                 Georgia                2465333
# 28  2019  United States                Kentucky                 858686
# 29  2019  United States               Louisiana                1055426
# 30  2019  United States             Mississippi                 475119
# 31  2019  United States          North Carolina                2350844
# 32  2019  United States          South Carolina                 985236
# 33  2019  United States               Tennessee                1520551
# 34  2019  United States                Virginia                2216845
# 35  2019  United States           West Virginia                 312758
# 36  2019  United States                 Arizona                1464760
# 37  2019  United States              New Mexico                 416005
# 38  2019  United States                Oklahoma                 824232
# 39  2019  United States                   Texas                7547824
# 40  2019  United States                Colorado                1561136
# 41  2019  United States                   Idaho                 323644
# 42  2019  United States                 Montana                 208677
# 43  2019  United States                    Utah                 754005
# 44  2019  United States                 Wyoming                 158585
# 45  2019  United States                  Alaska                 221625
# 46  2019  United States              California               12549876
# 47  2019  United States                  Hawaii                 389126
# 48  2019  United States                  Nevada                 710459
# 49  2019  United States                  Oregon                1006418
# 50  2019  United States              Washington                2398430
#
#     Population  GDP per Capita
# 0      3565287     320468170.0
# 1      1344212     200916225.0
# 2      6949503     342792139.0
# 3      1359711     260628178.0
# 4      1059361     239921991.0
# 5       623989     222984700.0
# 6       973764     309788614.0
# 7       705749     828592035.0
# 8      6045680     283401371.0
# 9      8882190     290397526.0
# 10    19453561     356111768.0
# 11    12801989     254183471.0
# 12    12671821     283187002.0
# 13     6732219     224059556.0
# 14     9986857     216905379.0
# 15    11689100     239011729.0
# 16     5822434     238598497.0
# 17     3155070     246952999.0
# 18     2913314     237725491.0
# 19     5639632     270127554.0
# 20     6137428     216430726.0
# 21     1934408     262688637.0
# 22      762062     299379840.0
# 23      884659     241022812.0
# 24     4903185     188423035.0
# 25     3017825     176525478.0
# 26    21477737     203624944.0
# 27    10617423     232196928.0
# 28     4467673     192199832.0
# 29     4648794     227032215.0
# 30     2976149     159642209.0
# 31    10488084     224144276.0
# 32     5148714     191355744.0
# 33     6833174     222524847.0
# 34     8535519     259720001.0
# 35     1792147     174515818.0
# 36     7278717     201238762.0
# 37     2096829     198397199.0
# 38     3956971     208298721.0
# 39    28995881     260306766.0
# 40     5758736     271090045.0
# 41     1787065     181103653.0
# 42     1068778     195248218.0
# 43     3205958     235188671.0
# 44      578759     274008698.0
# 45      731545     302954705.0
# 46    39512223     317620094.0
# 47     1415872     274831341.0
# 48     3080156     230656824.0
# 49     4217737     238615637.0
# 50     7614893     314965686.0

# %% [markdown]
# # Concat

# %%
# Concat data frame
clean_df = pd.concat([df_china, df_usa])

# Reset index
clean_df.reset_index(drop = True, inplace = True)

clean_df.head()
# Out:
#   Administrative Division                                     Characteristic  \
# 0               Guangdong  Export-oriented, digesting foreign advanced te...
# 1                 Jiangsu  Multifunctional manufacturing: Light industria...
# 2                Shandong                  High-tech R & D and manufacturing
# 3                Zhejiang  Multifunctional manufacturing: Light industria...
# 4                   Henan  Coal mining and coal deep processing, natural ...
#
#   Country                          Economic Zone  Economic Zone #  \
# 0   China                        Southeast Coast              4.0
# 1   China                             East Coast              3.0
# 2   China                            North Coast              2.0
# 3   China                             East Coast              3.0
# 4   China  Yellow River Upper and Middle Reaches              5.0
#
#    GDP per Capita  Nominal GDP (Billion)  Population  Region  Year
# 0         13976.0                 1561.0   111690000    East  2019
# 1         17985.0                 1444.0    80290000    East  2019
# 2         10294.0                 1030.0   100060000    East  2019
# 3         15980.0                  904.0    56570000    East  2019
# 4          8233.0                  787.0    95590000  Middle  2019

# %%
clean_df.to_csv('clean_data/clean_china_and_usa.csv')
