# %%
import pandas as pd
import numpy as np

# %%
# Load data
df_gdp_mainlandchina = pd.read_csv('raw_data/data-gdp-mainlandchina-2019.csv')  
df_gdp_usa = pd.read_csv('raw_data/data-gdp-usa-2019.csv')  
df_pop_china = pd.read_csv('raw_data/data-pop-china-2017.csv')  
df_pop_usa = pd.read_csv('raw_data/data-pop-usa-2019.csv')  
df_WEO = pd.read_csv('raw_data/WEO_Data.csv')  
df_region_china = pd.read_csv('raw_data/data-economyregion-china.csv')  
df_continent = pd.read_csv('raw_data/country-and-continent-codes-list-csv_csv.csv')

# %% [markdown]
# # Get data of China

# %%
# Merge dataframe for China
df_china = pd.DataFrame.merge(df_gdp_mainlandchina,df_pop_china,how='right',left_on='Provinces',right_on='Administrative Division')
df_china = pd.DataFrame.merge(df_china,df_region_china,how='left',left_on='Administrative Division',right_on='Provinces')

# Don't show Unnamed columns
df_china = df_china.loc[:, ~df_china.columns.str.contains('^Unnamed')] 

# Drop column
df_china = df_china.drop(['Provinces_x'], axis=1)
df_china = df_china.drop(['Provinces_y'], axis=1)

# Add column
df_china['Country'] = 'China'
df_china['Year'] = '2019'

# Concat 'CN' to all value in[Region]
df_china['Region'] = df_china['Region'].map(str) + '-CN'

df_china.tail()
# Out:
#     Nominal GDP (Billion) Administrative Division  Population        Region  \
# 29                   43.0                 Qinghai     5980000       West-CN
# 30                   25.0                   Tibet     3370000       West-CN
# 31                    NaN               Hong Kong     7335384  Hong Kong-CN
# 32                    NaN                   Macau      644900      Macau-CN
# 33                    NaN                  Taiwan    23562318     Taiwan-CN
#
#     Economic Zone #          Economic Zone         经济区  \
# 29               10  Qinghai-Tibet Plateau     青藏高原经济区
# 30               10  Qinghai-Tibet Plateau     青藏高原经济区
# 31               11              Hong Kong     香港特别行政区
# 32               12                  Macau    澳门港特别行政区
# 33               13                 Taiwan  台澎金马个别关税领域
#
#                                        Characteristic Country  Year
# 29  Natural gas, salt lake resources, non-ferrous ...   China  2019
# 30  Natural gas, salt lake resources, non-ferrous ...   China  2019
# 31  Trade and logistics industry (21.2%), financia...   China  2019
# 32                 Tourism and apparel industry (41%)   China  2019
# 33                      Agricultural products and OEM   China  2019

# %%
# Get GDP value for Hong Kong, Macau and Taiwan
df_hongkong = df_WEO[df_WEO['Country'].str.contains('hong kong', case=False, na=False)]
hongkong_gdp = df_hongkong.loc[df_hongkong['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

df_macau = df_WEO[df_WEO['Country'].str.contains('maca', case=False, na=False)]
macau_gdp = df_macau.loc[df_macau['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

df_taiwan = df_WEO[df_WEO['Country'].str.contains('taiwan', case=False, na=False)]
taiwan_gdp = df_taiwan.loc[df_taiwan['Subject Descriptor'] == 'Gross domestic product, current prices', '2019'].values[0]

print('Hong Kong GDP: ',hongkong_gdp)
print('Macau GDP: ',macau_gdp)
print('Taiwan GDP: ',taiwan_gdp)
# Out:
# Hong Kong GDP:  372.989
# Macau GDP:  55.136
# Taiwan GDP:  586.104

# %%
# Assign value
## to Hong Kong
hongkong_index = df_china.loc[df_china['Administrative Division'] == 'Hong Kong'].index[0]
df_china.at[hongkong_index, 'Nominal GDP (Billion)'] = hongkong_gdp

## to Macau
macau_index = df_china.loc[df_china['Administrative Division'] == 'Macau'].index[0]
df_china.at[macau_index, 'Nominal GDP (Billion)'] = macau_gdp

## to Taiwan 
taiwan_index = df_china.loc[df_china['Administrative Division'] == 'Taiwan'].index[0]
df_china.at[taiwan_index, 'Nominal GDP (Billion)'] = taiwan_gdp

# Calculate GDP per Capita
df_china['GDP per Capita'] = (df_china['Nominal GDP (Billion)'] / df_china['Population'])*1000000000

# Re-order Columns
df_china = df_china[['Year','Country','Region','Economic Zone #','Economic Zone','Administrative Division','Nominal GDP (Billion)','Population','GDP per Capita','Characteristic']]

# Set 0 decimal places
df_china['GDP per Capita'] = df_china['GDP per Capita'].round(0)

df_china
# Out:
#     Year Country                      Region  Economic Zone #  \
# 0   2019   China                     East-CN                4
# 1   2019   China                     East-CN                3
# 2   2019   China                     East-CN                2
# 3   2019   China                     East-CN                3
# 4   2019   China                   Middle-CN                5
# 5   2019   China                     West-CN                6
# 6   2019   China                   Middle-CN                6
# 7   2019   China                     East-CN                4
# 8   2019   China                   Middle-CN                6
# 9   2019   China                     East-CN                3
# 10  2019   China                   Middle-CN                6
# 11  2019   China                     East-CN                2
# 12  2019   China                     East-CN                2
# 13  2019   China                     West-CN                5
# 14  2019   China  Northeast Comprehensive-CN                1
# 15  2019   China                   Middle-CN                6
# 16  2019   China                     West-CN                6
# 17  2019   China                     West-CN                7
# 18  2019   China                     West-CN                7
# 19  2019   China                     West-CN                8
# 20  2019   China                   Middle-CN                5
# 21  2019   China                     West-CN                7
# 22  2019   China                     East-CN                2
# 23  2019   China  Northeast Comprehensive-CN                1
# 24  2019   China                     West-CN                9
# 25  2019   China  Northeast Comprehensive-CN                1
# 26  2019   China                     West-CN                5
# 27  2019   China                     East-CN                4
# 28  2019   China                     West-CN                5
# 29  2019   China                     West-CN               10
# 30  2019   China                     West-CN               10
# 31  2019   China                Hong Kong-CN               11
# 32  2019   China                    Macau-CN               12
# 33  2019   China                   Taiwan-CN               13
#
#                              Economic Zone Administrative Division  \
# 0                          Southeast Coast               Guangdong
# 1                               East Coast                 Jiangsu
# 2                              North Coast                Shandong
# 3                               East Coast                Zhejiang
# 4    Yellow River Upper and Middle Reaches                   Henan
# 5   Yangtze River Upper and Middle Reaches                 Sichuan
# 6   Yangtze River Upper and Middle Reaches                   Hubei
# 7                          Southeast Coast                  Fujian
# 8   Yangtze River Upper and Middle Reaches                   Hunan
# 9                               East Coast                Shanghai
# 10  Yangtze River Upper and Middle Reaches                   Anhui
# 11                             North Coast                 Beijing
# 12                             North Coast                   Hebei
# 13   Yellow River Upper and Middle Reaches                 Shaanxi
# 16  Rice and cotton, steel and non-ferrous metallu...
# 17  Chinese herbal medicine and biological product...
# 18  Chinese herbal medicine and biological product...
# 19  Energy sources such as coal, natural gas and h...
# 20  Coal mining and coal deep processing, natural ...
# 21  Chinese herbal medicine and biological product...
# 22                  High-tech R & D and manufacturing
# 23  Heavy industry, Energy raw materials, Agricult...
# 24  Cotton, oasis agriculture, fruits, tomatoes, w...
# 25  Heavy industry, Energy raw materials, Agricult...
# 26  Coal mining and coal deep processing, natural ...
# 27  Export-oriented, digesting foreign advanced te...
# 28  Coal mining and coal deep processing, natural ...
# 29  Natural gas, salt lake resources, non-ferrous ...
# 30  Natural gas, salt lake resources, non-ferrous ...
# 31  Trade and logistics industry (21.2%), financia...
# 32                 Tourism and apparel industry (41%)
# 33                      Agricultural products and OEM

# %% [markdown]
# # Get data of USA

# %%
df_gdp_usa.head()
# Out:
#             State       Region  Nominal GDP (Billion)
# 0     Connecticut  New England                 288.99
# 1          Maine   New England                  68.44
# 2  Massachusetts   New England                 604.21
# 3  New Hampshire   New England                  89.84
# 4   Rhode Island   New England                  64.44

# %%
df_pop_usa.head()
# Out:
#            State  Population
# 0     California    39512223
# 1          Texas    28995881
# 2        Florida    21477737
# 3       New York    19453561
# 4   Pennsylvania    12801989

# %%
# Strip leading and trailng white space in State column
df_gdp_usa['State'] = df_gdp_usa['State'].str.strip()
df_pop_usa['State'] = df_pop_usa['State'].str.strip()

# Merge dataframe for China
df_usa = pd.DataFrame.merge(df_gdp_usa,df_pop_usa,how='left',on='State')

# Add column
df_usa['Country'] = 'United States'
df_usa['Year'] = '2019'

# Rename column
df_usa.rename(columns={'State':'Administrative Division'}, inplace=True)

# Re-order Columns
df_usa = df_usa[['Year','Country','Region','Administrative Division','Nominal GDP (Billion)','Population']]

# Calculate GDP per Capita
df_usa['GDP per Capita'] = (df_usa['Nominal GDP (Billion)'] / df_usa['Population'])*1000000000

# Set 0 decimal places
df_usa['GDP per Capita'] = df_usa['GDP per Capita'].round(0)

# Concat 'US' to all value in[Region]
df_usa['Region'] = df_usa['Region'].map(str) + '-US'

df_usa
# Out:
#     Year        Country             Region Administrative Division  \
# 0   2019  United States     New England-US             Connecticut
# 1   2019  United States     New England-US                   Maine
# 2   2019  United States     New England-US           Massachusetts
# 3   2019  United States     New England-US           New Hampshire
# 4   2019  United States     New England-US            Rhode Island
# 5   2019  United States     New England-US                 Vermont
# 6   2019  United States         Mideast-US                Delaware
# 7   2019  United States         Mideast-US    District of Columbia
# 8   2019  United States         Mideast-US                Maryland
# 9   2019  United States         Mideast-US              New Jersey
# 10  2019  United States         Mideast-US                New York
# 11  2019  United States         Mideast-US            Pennsylvania
# 12  2019  United States     Great Lakes-US                Illinois
# 13  2019  United States     Great Lakes-US                 Indiana
# 14  2019  United States     Great Lakes-US                Michigan
# 15  2019  United States     Great Lakes-US                    Ohio
# 16  2019  United States     Great Lakes-US               Wisconsin
# 38                 207.38     3956971         52409.0
# 39                1918.07    28995881         66150.0
# 40                 396.37     5758736         68829.0
# 41                  82.27     1787065         46036.0
# 42                  52.95     1068778         49543.0
# 43                 192.01     3205958         59892.0
# 44                  39.79      578759         68751.0
# 45                  55.76      731545         76222.0
# 46                3183.25    39512223         80564.0
# 47                  98.54     1415872         69597.0
# 48                 180.41     3080156         58572.0
# 49                 255.42     4217737         60559.0
# 50                 610.49     7614893         80171.0

# %% [markdown]
# # Concat

# %%
# Concat data frame
clean_df = pd.concat([df_china, df_usa])

# Reset index
clean_df.reset_index(drop = True, inplace = True)

clean_df.head()
# Out:
#   Administrative Division                                     Characteristic  \
# 0               Guangdong  Export-oriented, digesting foreign advanced te...
# 1                 Jiangsu  Multifunctional manufacturing: Light industria...
# 2                Shandong                  High-tech R & D and manufacturing
# 3                Zhejiang  Multifunctional manufacturing: Light industria...
# 4                   Henan  Coal mining and coal deep processing, natural ...
#
#   Country                          Economic Zone  Economic Zone #  \
# 0   China                        Southeast Coast              4.0
# 1   China                             East Coast              3.0
# 2   China                            North Coast              2.0
# 3   China                             East Coast              3.0
# 4   China  Yellow River Upper and Middle Reaches              5.0
#
#    GDP per Capita  Nominal GDP (Billion)  Population     Region  Year
# 0         13976.0                 1561.0   111690000    East-CN  2019
# 1         17985.0                 1444.0    80290000    East-CN  2019
# 2         10294.0                 1030.0   100060000    East-CN  2019
# 3         15980.0                  904.0    56570000    East-CN  2019
# 4          8233.0                  787.0    95590000  Middle-CN  2019

# %%
clean_df.to_csv('clean_data/clean_china_and_usa.csv')

# %% [markdown]
# # Get data of Europe

# %%
df_continent.head()
# Out:
#   Continent_Name Continent_Code                                  Country_Name  \
# 0           Asia             AS              Afghanistan, Islamic Republic of
# 1         Europe             EU                          Albania, Republic of
# 2     Antarctica             AN  Antarctica (the territory South of 60 deg S)
# 3         Africa             AF      Algeria, People's Democratic Republic of
# 4        Oceania             OC                                American Samoa
#
#   Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 0                      AF                       AFG             4.0
# 1                      AL                       ALB             8.0
# 2                      AQ                       ATA            10.0
# 3                      DZ                       DZA            12.0
# 4                      AS                       ASM            16.0

# %%
# Clean data in ['Country']
df_continent['Country'] = df_continent['Country_Name'].str.rsplit(',').str[0] 
df_continent.head()
# Out:
#   Continent_Name Continent_Code                                  Country_Name  \
# 0           Asia             AS              Afghanistan, Islamic Republic of
# 1         Europe             EU                          Albania, Republic of
# 2     Antarctica             AN  Antarctica (the territory South of 60 deg S)
# 3         Africa             AF      Algeria, People's Democratic Republic of
# 4        Oceania             OC                                American Samoa
#
#   Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number  \
# 0                      AF                       AFG             4.0
# 1                      AL                       ALB             8.0
# 2                      AQ                       ATA            10.0
# 3                      DZ                       DZA            12.0
# 4                      AS                       ASM            16.0
#
#                                         Country
# 0                                   Afghanistan
# 1                                       Albania
# 2  Antarctica (the territory South of 60 deg S)
# 3                                       Algeria
# 4                                American Samoa

# %%
df_WEO.head()
# Out:
#        Country                                 Subject Descriptor  \
# 0  Afghanistan             Gross domestic product, current prices
# 1  Afghanistan  Gross domestic product per capita, current prices
# 2  Afghanistan                 Inflation, average consumer prices
# 3  Afghanistan                                  Unemployment rate
# 4  Afghanistan                                         Population
#
#                           Units     Scale     2017     2018     2019     2020  \
# 0                  U.S. dollars  Billions   20.235    19.63   18.734   18.861
# 1                  U.S. dollars     Units  569.531  544.983  513.108  509.759
# 2                         Index       NaN  110.998  111.693  114.583  119.742
# 3  Percent of total labor force       NaN      NaN      NaN      NaN      NaN
# 4                       Persons  Millions    35.53    36.02    36.51       37
#
#       2021     2022     2023     2024  Estimates Start After
# 0   19.998    21.54   23.237    25.19                 2018.0
# 1  533.089  566.416  602.884   644.95                 2016.0
# 2  125.427  131.699  138.284  145.198                 2018.0
# 3      NaN      NaN      NaN      NaN                    NaN
# 4   37.514   38.028   38.543   39.057                 2016.0

# %%
# Select columns based on condition
df_gdp_world = df_WEO[['Country','Units','Scale','2019']][df_WEO['Subject Descriptor'] == 'Gross domestic product, current prices']#[df_WEO['2019']]
df_gdp_world.head()
# Out:
#                 Country         Units     Scale     2019
# 0           Afghanistan  U.S. dollars  Billions   18.734
# 5               Albania  U.S. dollars  Billions   15.418
# 10              Algeria  U.S. dollars  Billions  172.781
# 15               Angola  U.S. dollars  Billions   91.527
# 20  Antigua and Barbuda  U.S. dollars  Billions    1.688

# %%
# Merge dataframe 
df_world = pd.DataFrame.merge(df_gdp_world,df_continent,how='left',on='Country')

# Select Europe gdp data
df_europe = df_world[['Country','2019']][df_world['Continent_Name'] == 'Europe']
df_europe
# Out:
#                     Country      2019
# 1                   Albania    15.418
# 6                   Armenia    13.444
# 10                  Austria   447.718
# 11               Azerbaijan    47.171
# 17                  Belarus    62.572
# 18                  Belgium   517.609
# 23   Bosnia and Herzegovina    20.106
# 27                 Bulgaria     66.25
# 44                  Croatia    60.702
# 45                   Cyprus     24.28
# 47           Czech Republic   246.953
# 48                  Denmark   347.176
# 57                  Estonia    31.038
# 61                  Finland   269.654
# 62                   France  2,707.07
# 65                  Georgia    15.925
# 67                  Germany  3,863.34
# 69                   Greece   214.012
# 78                  Hungary   170.407
# 79                  Iceland    23.918
# 84                  Ireland    384.94
# 86                    Italy  1,988.64
# 90               Kazakhstan   170.326
# 100                  Latvia    35.045
# 105               Lithuania    53.641
# 106              Luxembourg    69.453
# 113                   Malta    14.859
# 119                 Moldova    11.688
# 121              Montenegro     5.424
# 128             Netherlands   902.355
# 134                  Norway   417.627
# 143                  Poland   565.854
# 144                Portugal   236.408
# 147                 Romania   243.698
# 151              San Marino     1.591
# 155                  Serbia    51.523
# 160                Slovenia    54.154
# 165                   Spain  1,397.87
# 172                  Sweden   528.929
# 173             Switzerland    715.36
# 184                  Turkey   743.708
# 189                 Ukraine   150.401
